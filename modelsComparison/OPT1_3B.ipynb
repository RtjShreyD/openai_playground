# %%
Comparison Sheet:"https://docs.google.com/spreadsheets/d/1pOnwAd2ra6gtWkpITki9rOwO0hGX6lUR_yUcZPILwMY/edit#gid=0"

# %%
# !nvidia-smi
#To check the available GPU
# Out:
# Mon Dec 18 17:55:53 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install -q torch>=2.0.0 palm-rlhf-pytorch transformers datasets tokenizers hidet wandb

# %%
from transformers import pipeline
generator = pipeline('text-generation', model="facebook/opt-1.3b")
generator("What are we having for dinner?")
# Out:
# config.json:   0%|          | 0.00/653 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# [{'generated_text': "What are we having for dinner?\nI'm not sure. I'm not a chef. I"}]

# %%
from transformers import pipeline, set_seed

set_seed(32)
generator = pipeline('text-generation', model="facebook/opt-1.3b", do_sample=True)
generator("What is a computer?")
# Out:
# CPU times: user 27.4 s, sys: 7.22 s, total: 34.6 s
# Wall time: 53.3 s
# [{'generated_text': 'What is a computer?\nA video game console\nWait wait... so it’s a'}]

# %%
# %%time
generator("Magnetism is")
# Out:
# CPU times: user 8.66 s, sys: 22.7 ms, total: 8.68 s
# Wall time: 11.9 s
# [{'generated_text': "explain computer?\nSorry I think it's a computer.\nI was hoping it was a"}]

# %%
from transformers import pipeline, set_seed

set_seed(32)
generator = pipeline('text-generation', model="facebook/opt-1.3b", do_sample=True, num_return_sequences=5)
generator("Computer is a")
